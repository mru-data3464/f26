# %%
# The usual imports
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.tree import DecisionTreeClassifier

#TODO: import your categorical data encoders from sklearn.preprocessing

# Note: you'll need to pip install ucimlrepo
# Alternatively, you can download the CSV from https://archive.ics.uci.edu/dataset/14/breast+cancer
from ucimlrepo import fetch_ucirepo

# %%
# fetch dataset 
breast_cancer = fetch_ucirepo(id=14) 
  
# data (as pandas dataframes) 
X = breast_cancer.data.features 
target = breast_cancer.data.targets 

X.info()

# %%
#TODO: inspect the target and convert it to a numerical feature "y"
# Hint: You don't need scikit-learn for this!

# %%
# There are some weird dates instead of numbers in this dataset, e.g. in tumor-size.
# Convert them to strings consistent with the rest of the data
X.replace("14-Oct", "10-14", inplace=True)
X.replace("9-May", "5-9", inplace=True)
X.replace("11-Sep", "9-11", inplace=True)
X.replace("14-Dec", "12-14", inplace=True)
X.replace("5-Mar", "3-5", inplace=True)
X.replace("8-Jun", "6-8", inplace=True)

# %%
# Split the data into test/train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8675309)

# %%
#TODO: explore X_train to get a sense of the data — cardinality and nominal vs ordinal
# Hint: try X_train[feat].value_counts().sort_index().plot(kind="bar")

# %%
#TODO: look at the one continuous value

# %%
#TODO: define encoders for each categorical variable, using ordinal or one-hot encoding as appropriate

pipeline = make_pipeline(
    make_column_transformer(
        #TODO: categorical encoders here
        ("passthrough", ["deg-malig"]) # this one just passes it through untransformed
    ),
    DecisionTreeClassifier()
)
pipeline

# %%
# TODO: cross-validate and tweak

# %%
# TODO: stretch goal: Which feature is the most important for predicting recurrence?
